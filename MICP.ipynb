# %% [markdown]
# # MEDICAL INSURANCE COST PREDICTION PROJECT

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# ## Data Reading from csv file

# %%
data = pd.read_csv('medical_insurance.csv')

# %%
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 2767   47  female  45.320         1     no  southeast   8569.86180
# 2768   21  female  34.600         0     no  southwest   2020.17700
# 2769   19    male  26.030         1    yes  northwest  16450.89470
# 2770   23    male  18.715         0     no  northwest  21595.38229
# 2771   54    male  31.600         0     no  southwest   9850.43200
#
# [2772 rows x 7 columns]

# %% [markdown]
# ## DATA CLEANING

# %%
# Check for Null values

# %%
data.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ## Framing 15 Questions

# %%
# Q1. Which region has more number of people with medical insurance?
# Q2. How amount of medical expense vary with the region?
# Q3. What is the proportion and number of smokers in the given data?
# Q4. Do being a smoker or not affect the amount of medical expense?
# Q5. Smokers are mainly male or female?
# Q6. Which region has more number of smokers?
# Q7. How number of childrens affect the amount of medical expenses?
# Q8. What is the number of parents and non parents population in the given dataset?
# Q9. What is the average BMI of the population?
# Q10. How BMI of a person affects the medical expense amount?
# Q11. How amount of medical expenses vary among males and females - Who spends more?
# Q12. Is there any correlation between age and BMI?
# Q13. What is the proportion of Males and Females who have taken medical insurance?
# Q14. Which age group of people are more present in the dataset?
# Q15. How charges vary wih respect to age of the person?

# %% [markdown]
# ### Q1. Which region has more number of people with medical insurance?

# %%
sb.countplot(x = data['region'])
# Out:
# <AxesSubplot:xlabel='region', ylabel='count'>

# %%
data['region'].value_counts().plot(kind = 'pie', autopct = '%.2f%%')
# Out:
# <AxesSubplot:ylabel='region'>

# %%
# Conclusion : The data set contains people from Southeast more.

# %% [markdown]
# ### Q2. How amount of medical expense vary with the region?

# %%
sb.barplot(x = data['region'] , y = data['charges'])
# Out:
# <AxesSubplot:xlabel='region', ylabel='charges'>

# %%
sb.boxplot(x = data['region'] , y = data['charges'])
# Out:
# <AxesSubplot:xlabel='region', ylabel='charges'>

# %%
# Conclusion : People from Southeast region has more medical expenses. There are a lot of outliers in the data.

# %% [markdown]
# ### Q3. What is the proportion and number of smokers in the given data?

# %%
data.value_counts('smoker')
# Out:
# smoker
# no     2208
# yes     564
# dtype: int64

# %%
data['smoker'].value_counts().plot(kind = 'pie', autopct = '%0.2f%%')
# Out:
# <AxesSubplot:ylabel='smoker'>

# %%
sb.countplot(x = data['smoker'])
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
# Conclusion : There are total 564 smokers in the given dataset which forms 20.35% of the total population.

# %% [markdown]
# ### Q4. Do being a smoker or not affect the amount of medical expense?

# %%
sb.barplot( x = data['smoker'], y = data['charges'])
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='charges'>

# %%
sb.boxplot( x = data['smoker'], y = data['charges'])
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='charges'>

# %%
# Conclusion : Smokers get more medical charges. There are few outliers present in this column data.

# %% [markdown]
# ### Q5. Smokers are mainly male or female?

# %%
pd.crosstab(data['sex'],data['smoker'])
# Out:
# smoker    no  yes
# sex
# female  1134  232
# male    1074  332

# %%
sb.heatmap(pd.crosstab(data['sex'],data['smoker']))
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='sex'>

# %%
#Conclusion : There are more male smokers.

# %% [markdown]
# ### Q6. Which region has more number of smokers?

# %%
pd.crosstab(data['region'],data['smoker'])
# Out:
# smoker      no  yes
# region
# northeast  522  136
# northwest  546  118
# southeast  574  192
# southwest  566  118

# %%
sb.heatmap(pd.crosstab(data['region'],data['smoker']))
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='region'>

# %%
# Conclusion : Southeast region has maximum number of smokers

# %% [markdown]
# ### Q7. How number of children affect the amount of medical expenses?

# %%
sb.barplot(x = data['children'] , y = data['charges'])
# Out:
# <AxesSubplot:xlabel='children', ylabel='charges'>

# %%
# Conclusion : The amount of medical expense increases with the number of children upto a certain level. Once the number of children reaches 3, the amount of medical expense decreases.

# %% [markdown]
# ### Q8. What is the number of parent and non parent population in the given dataset?

# %%
sb.countplot(x = data['children'])
# Out:
# <AxesSubplot:xlabel='children', ylabel='count'>

# %%
data.value_counts('children')
# Out:
# children
# 0    1186
# 1     672
# 2     496
# 3     324
# 4      52
# 5      42
# dtype: int64

# %%
# Conclusion : There are total 1186 non parents and 1586 parents.

# %% [markdown]
# ### Q9. What is the average BMI of the population?

# %%
sb.histplot(x = data['bmi'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='Count'>

# %%
data['bmi'].mean()
# Out:
# 30.70134920634921

# %%
data['bmi'].describe()
# Out:
# count    2772.000000
# mean       30.701349
# std         6.129449
# min        15.960000
# 25%        26.220000
# 50%        30.447500
# 75%        34.770000
# max        53.130000
# Name: bmi, dtype: float64

# %%
# Conclusion : Average bmi value of the population is  30.7013

# %% [markdown]
# ### Q10. How BMI of a person affects the medical expense amount?

# %%
sb.scatterplot(x = data['bmi'], y =data['charges'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
# Conclusion : The variation shows that the amount of medical charges are assigned more to the people with more bmi. There are outliers present in the data.

# %% [markdown]
# ### Q11. How amount of medical expenses vary among males and females - Who has more medical expenses?

# %%
sb.barplot( x = data['sex'], y = data['charges'])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='charges'>

# %%
# Conclusion : Males have more medical expenses.

# %% [markdown]
# ### Q12.  Is there any correlation between age and BMI?

# %%
data['bmi'].corr(data['age'])
# Out:
# 0.11304845107996198

# %%
sb.scatterplot(x = data['age'], y = data['bmi'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='bmi'>

# %%
# Conclusion : Correlation between age and bmi is 0.11 which is a weak positive correlation.

# %% [markdown]
# ### Q13. What is the proportion of Males and Females who have taken medical insurance?

# %%
sb.countplot(x = data['sex'])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
data['sex'].value_counts()
# Out:
# male      1406
# female    1366
# Name: sex, dtype: int64

# %%
data['sex'].value_counts().plot(kind = 'pie', autopct = '%0.2f%%')
# Out:
# <AxesSubplot:ylabel='sex'>

# %%
# Conclusion : More number of Males are there who have taken medical insurance from the given company.

# %% [markdown]
# ### Q14. Which age group of people are more present in the dataset ?

# %%
sb.histplot(data['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sb.distplot(data['age'])
# Out:
# C:\Users\Pramod\anaconda3\envs\workshop\lib\site-packages\ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
# Conclusion : Although the data is ditsributed almost normally i.e. nearly all age groups have equal frequency but people between 18 to 22 are more.

# %% [markdown]
# ### Q15. How charges vary with respect to age of the person?

# %%
sb.scatterplot(y = data['charges'], x = data['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='charges'>

# %%
# Conclusion : More is the age of the person, More is the medical expense amount.

# %%
sb.pairplot(data)

# %% [markdown]
# ## DATA PREPROCESSING

# %% [markdown]
# ### To convert categorical data into numerical values

# %%
data['sex'] = data['sex'].replace({'male':0,'female':1})

# %%
data
# Out:
#       age  sex     bmi  children smoker     region      charges
# 0      19    1  27.900         0    yes  southwest  16884.92400
# 1      18    0  33.770         1     no  southeast   1725.55230
# 2      28    0  33.000         3     no  southeast   4449.46200
# 3      33    0  22.705         0     no  northwest  21984.47061
# 4      32    0  28.880         0     no  northwest   3866.85520
# ...   ...  ...     ...       ...    ...        ...          ...
# 2767   47    1  45.320         1     no  southeast   8569.86180
# 2768   21    1  34.600         0     no  southwest   2020.17700
# 2769   19    0  26.030         1    yes  northwest  16450.89470
# 2770   23    0  18.715         0     no  northwest  21595.38229
# 2771   54    0  31.600         0     no  southwest   9850.43200
#
# [2772 rows x 7 columns]

# %%
data['smoker'] = data['smoker'].replace({'yes':1,'no':0})

# %%
data.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19    1  27.900         0       1  southwest  16884.92400
# 1   18    0  33.770         1       0  southeast   1725.55230
# 2   28    0  33.000         3       0  southeast   4449.46200
# 3   33    0  22.705         0       0  northwest  21984.47061
# 4   32    0  28.880         0       0  northwest   3866.85520

# %%
data['region'] = data['region'].replace({'northeast':1,'northwest':2,'southeast':3,'southwest':4})

# %%
data.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    1  27.900         0       1       4  16884.92400
# 1   18    0  33.770         1       0       3   1725.55230
# 2   28    0  33.000         3       0       3   4449.46200
# 3   33    0  22.705         0       0       2  21984.47061
# 4   32    0  28.880         0       0       2   3866.85520

# %%
sb.pairplot(data)

# %% [markdown]
# ### To check for outliers in charges

# %%
sb.boxplot(data['charges'])
# Out:
# <AxesSubplot:>

# %%
# Finding outliers through IQR Method

# %%
data_chr = data['charges']
type(data_chr)
# Out:
# pandas.core.series.Series

# %%
out_df = pd.DataFrame()
out_df['Columns']= ['charges']
out_df.set_index('Columns', inplace = True)
out_df['Min'] = data_chr.min()
out_df['Max']= data_chr.max()
out_df['Range']= data_chr.max()-data.min()
out_df['Q1'] = data_chr.quantile(.25)
out_df['Q3'] = data_chr.quantile(.75)
out_df['IQR'] = data_chr.quantile(.75) - data_chr.quantile(.25)
out_df['LF'] = out_df['Q1']-(1.5 * out_df['IQR'])
out_df['UF'] = out_df['Q3']+(1.5 * out_df['IQR'])
out_df
# Out:
#                Min          Max        Range        Q1          Q3  \
# Columns
# charges  1121.8739  63770.42801  62648.55411  4687.797  16577.7795
#
#                 IQR           LF           UF
# Columns
# charges  11889.9825 -13147.17675  34412.75325

# %%
def outlier(x,lf,uf):
    LO,UO = [],[]
    for i in data[x]:
        if i < lf:
            LO.append(i)
        elif i>uf:
                UO.append(i)
               
                return LO,UO

# %%
outlier_list = []
outlier_list.append( outlier('charges',-13147.17675,34412.75325))
out_df['outlier'] = outlier_list
out_df
# Out:
#                Min          Max        Range        Q1          Q3  \
# Columns
# charges  1121.8739  63770.42801  62648.55411  4687.797  16577.7795
#
#                 IQR           LF           UF             outlier
# Columns
# charges  11889.9825 -13147.17675  34412.75325  ([], [39611.7577])

# %% [markdown]
# ### To remove outliers

# %%
data [data["charges"] == 39611.7577]
# Out:
#       age  sex    bmi  children  smoker  region     charges
# 14     27    0  42.13         0       1       3  39611.7577
# 1340   27    0  42.13         0       1       3  39611.7577
# 1400   27    0  42.13         0       1       3  39611.7577
# 2726   27    0  42.13         0       1       3  39611.7577

# %%
data.drop([14], axis=0, inplace=True)
data.drop([1340], axis=0, inplace=True)
data.drop([1400], axis=0, inplace=True)
data.drop([2726], axis=0, inplace=True)

# %%
data
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    1  27.900         0       1       4  16884.92400
# 1      18    0  33.770         1       0       3   1725.55230
# 2      28    0  33.000         3       0       3   4449.46200
# 3      33    0  22.705         0       0       2  21984.47061
# 4      32    0  28.880         0       0       2   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 2767   47    1  45.320         1       0       3   8569.86180
# 2768   21    1  34.600         0       0       4   2020.17700
# 2769   19    0  26.030         1       1       2  16450.89470
# 2770   23    0  18.715         0       0       2  21595.38229
# 2771   54    0  31.600         0       0       4   9850.43200
#
# [2768 rows x 7 columns]

# %% [markdown]
# ## PREDICTION USING LINEAR REGRESSION MODEL

# %%
x = data.drop(columns = 'charges', axis = 1)
x
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    1  27.900         0       1       4
# 1      18    0  33.770         1       0       3
# 2      28    0  33.000         3       0       3
# 3      33    0  22.705         0       0       2
# 4      32    0  28.880         0       0       2
# ...   ...  ...     ...       ...     ...     ...
# 2767   47    1  45.320         1       0       3
# 2768   21    1  34.600         0       0       4
# 2769   19    0  26.030         1       1       2
# 2770   23    0  18.715         0       0       2
# 2771   54    0  31.600         0       0       4
#
# [2768 rows x 6 columns]

# %%
y = data['charges']
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 2767     8569.86180
# 2768     2020.17700
# 2769    16450.89470
# 2770    21595.38229
# 2771     9850.43200
# Name: charges, Length: 2768, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,random_state = 1)
x_train.shape
# Out:
# (2076, 6)

# %%
y_train.shape
# Out:
# (2076,)

# %%
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
linreg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
linreg.intercept_
# Out:
# -11739.566263538281

# %%
linreg.coef_
# Out:
# array([  257.36864607,   -63.0129512 ,   348.51397997,   507.51591683,
#        23445.10188361,  -460.47148142])

# %%
y_pred = linreg.predict(x_test)
y_pred
# Out:
# array([ 8.57438983e+03,  5.87533769e+03,  1.01874879e+04,  1.12520408e+04,
#         4.85766236e+03,  2.52204331e+03,  4.15798100e+02,  1.31841117e+04,
#         4.45198749e+03,  1.33670031e+04,  4.78975712e+03,  1.47799028e+04,
#         3.15081670e+04,  1.52841108e+04,  6.18127654e+03,  5.19771919e+03,
#         1.52360029e+04,  1.28187291e+04,  3.87308910e+04,  1.36898511e+04,
#         8.78128389e+03,  3.37554768e+03,  1.66969507e+04,  2.56284511e+04,
#         6.93550462e+03,  8.48318631e+03,  8.50293508e+03,  3.17837037e+04,
#         1.01771656e+04,  6.67541830e+03,  6.48037933e+03,  9.87214782e+03,
#         9.92844175e+03,  1.47526664e+04,  3.63387116e+04,  1.62446450e+04,
#         1.02979785e+04,  1.77544043e+03,  3.14117586e+04,  1.26826019e+04,
#         1.13898218e+04,  1.58348714e+04,  3.92664730e+03,  3.08058808e+04,
#         4.29138213e+03,  5.17649305e+03,  1.30242931e+04,  1.08167875e+04,
# ...

# %%
plt.scatter(y_test, y_pred, color='green')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--')
plt.xlabel('Actual Charges Values')
plt.ylabel('Predicted Charges Values')
# Out:
# Text(0, 0.5, 'Predicted Charges Values')

# %% [markdown]
# ### MODEL EVALUATION

# %% [markdown]
# #### Through MAE (Mean Absolute Error)

# %%
from sklearn import metrics
print (metrics.mean_absolute_error(y_test, y_pred))
# Out:
# 4336.634343245947

# %% [markdown]
# #### Through MSE (Mean Squared Error)

# %%
MSE = metrics.mean_squared_error(y_test, y_pred)
MSE
# Out:
# 38785111.16513904

# %% [markdown]
# #### Through RMSE (Root Mean Squared Error)

# %%
RMSE = np.sqrt(MSE)
RMSE
# Out:
# 6227.769357092397

# %% [markdown]
# #### Through R2 (Goodness of fit test)

# %%
R2 =metrics.r2_score(y_test, y_pred)
R2
# Out:
# 0.7589364870054081

# %%
# Conclusion : R2 value is 0.75 which is a good value and the model fits into the data. (The value of R2 should be close to one for better model)

# %% [markdown]
# ### TO USE THE MODEL

# %%
# input (age,sex,bmi,children,smoker,region)
input_data = (25,1,30,0,0,3)
#To change input data into an array
input_array = np.array(input_data)
input_array_reshape = input_array.reshape(1,-1)
input_array_reshape
# Out:
# array([[25,  1, 30,  0,  0,  3]])

# %%
prediction = linreg.predict(input_array_reshape)
prediction
# Out:
# C:\Users\Pramod\anaconda3\envs\workshop\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([3705.64189185])

# %%
input_data2 = (40,0,45,2,1,3)
#To change input data into an array
input_array2 = np.array(input_data2)
input_array_reshape2 = input_array2.reshape(1,-1)
input_array_reshape2
# Out:
# array([[40,  0, 45,  2,  1,  3]])

# %%
prediction2 = linreg.predict(input_array_reshape2)
prediction2
# Out:
# C:\Users\Pramod\anaconda3\envs\workshop\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([37317.02795095])

# %% [markdown]
# # THANK YOU
